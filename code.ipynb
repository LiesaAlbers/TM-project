# %% [markdown]
# #### Import Necessary Modules/Libraries

# %%
import os
import requests
import csv
from bs4 import BeautifulSoup
import time
import re

# %% [markdown]
# #### Define Functions

# %%
def scrape_billboard(year):
    """
    Scrapes the Billboard Year-End Hot 100 singles for a given year.

    Args:
        year (str): The year for which to scrape the Billboard data.

    Returns:
        list: A list of tuples containing the year, rank, song title, and artist name of each song for the given year.
    """
    # Construct URL using year
    url = f'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_{year}'
    
    response = requests.get(url)
    response.raise_for_status()  # Raise an error for bad responses
    document = BeautifulSoup(response.text, 'html.parser')

    # Find list of songs on webpage
    songs_table = document.find('table', class_='wikitable')
    song_data = []

    # Get the top 10 songs
    for row in songs_table.find_all('tr')[1:11]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) > 2:
            rank = columns[0].text.strip()
            song_title = columns[1].text.strip().replace('"', '')  # Remove quotes
            artist_name = columns[2].text.strip()
            song_data.append((year, rank, song_title, artist_name))

    return song_data # Returns list of tuples (year, rank, song_title, artist_name)


def format_song_data(song_data):
    """
    Formats the song data by cleaning the artist names and song titles.

    Args:
        song_data (list): A list of tuples containing the year, rank, song title, and artist name.

    Returns:
        list: A list of formatted tuples containing the year, rank, cleaned song title, and cleaned artist name.
    """
    # Initialise empty list for formatted data
    formatted_data = []
    
    for year, rank, song_title, artist_name in song_data:
        # Extract and clean the first artist's name
        formatted_artist = artist_name.split(" featuring ")[0]  # Get only the first artist
        formatted_artist = formatted_artist.split(" and ")[0]  # Get only the first artist in case of "and"
        formatted_artist = re.sub(r'\(.*?\)|\[.*?\]', '', formatted_artist)
        formatted_artist = re.sub(r'[^\w\s]', '', formatted_artist) 
        formatted_artist = formatted_artist.lower().replace(" ", "")

        # Replace specific artist names
        artist_replacements = {
            'matchboxtwenty': 'matchbox20',
            'thecalling' : 'calling',
            'beyoncé' : 'beyonceknowles',
            'thepussycatdolls' : 'pussycatdolls',
            'theblackeyedpeas' : 'blackeyedpeas',
            'theallamericanrejects' : 'allamericanrejects',
            'kesha' : 'keha',
            'thewanted' : 'wanted',
            'macklemoreryanlewis' : 'macklemore',
            'silentó' : 'silento',
            'theweeknd' : 'weeknd',
            'thechainsmokers' : 'chainsmokers',
            'cardibbadbunny' : 'cardi-b',
            'zeddmarenmorris' : 'zedd'
        }
        
        # Replace the artist name if it matches any key in the replacements dictionary
        formatted_artist = artist_replacements.get(formatted_artist, formatted_artist)

        # Clean song title 
        formatted_title = re.sub(r'\(.*?\)|\[.*?\]', '', song_title)
        formatted_title = re.sub(r'[^\w\s]', '', formatted_title)  
        formatted_title = formatted_title.lower().replace(" ", "")

        # Replace specific song titles
        title_replacements = {
            'independentwomenparti': 'independentwomen',
            'buyuadrank' : 'buyuadrankshawtysnappin',
            'singleladies' : 'singleladiesputaringonit',
            'igottafeeling' : 'igottafeelin',
            'stronger' : 'whatdoesntkillyoustronger',
            'watchme' : 'watchmewhipnaenae'
        }
        
        # Replace the title if it matches any key in the replacements dictionary
        formatted_title = title_replacements.get(formatted_title, formatted_title)
        
        # Append formatted tuple to list
        formatted_data.append((year, rank, formatted_title, formatted_artist))
        
    return formatted_data


def scrape_lyrics(formatted_title, formatted_artist):
    """
    Scrapes the lyrics for a given song and artist from AZLyrics.

    Args:
        song_title (str): The title of the song.
        artist_name (str): The name of the artist.

    Returns:
        str: The lyrics of the song, or None if an error occurs.
    """
    # Construct URL using formatted title and artist
    url = f'https://www.azlyrics.com/lyrics/{formatted_artist}/{formatted_title}.html'
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad responses
        document = BeautifulSoup(response.text, 'html.parser')

        # Find all <div> elements where lyrics are found
        lyrics_tag = document.find_all("div", attrs={"class": None, "id": None})

        # Initialise empty list to store lyrics
        lyrics = []

        # Extract text from each lyric tag, strip leading/trailing whitespace and append to list
        lyrics = [content.get_text(separator=" ").strip() for content in lyrics_tag]

        # Join lines to form complete lyrics
        lyrics_text = "\n".join(lyrics)

        return lyrics_text

    # Print error message if issue fetching the lyrics
    except requests.exceptions.RequestException as e:
        print(f"Error fetching lyrics for {formatted_title} by {formatted_artist}: {e}")
        return None 


def save_lyrics_to_file(year, lyrics):
    """
    Saves the combined lyrics to a text file for the given year.

    Args:
        year (str): The year for which the lyrics are being saved.
        lyrics (str): The lyrics to save in the text file.
    """
    # Use 'primary_set' for 00s and 'secondary_set' for 10s
    if year in decade_1:
        directory = 'primary_set'
    else:
        directory = 'secondary_set'
    
    os.makedirs(directory, exist_ok=True)  # Create directory if it doesn't exist
    with open(f'{directory}/{year}.txt', 'a', encoding='utf-8') as lyric_file:
        lyric_file.write(lyrics + "\n\n")  # Append lyrics for the year


def create_csv_file(songs, filename='overview.csv'):
    """
    Creates a CSV file from the list of songs.

    Args:
        songs (list): A list of tuples containing the year, rank, song title, and artist name.
        filename (str): The name of the CSV file to create (default is 'overview.csv').
    """  
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['Year', 'Rank', 'Song Title', 'Artist'])  # Write header
        for year, rank, song_title, artist_name in songs:
            print(f"Writing to CSV: Year={year}, Rank={rank}, Title={song_title}, Artist={artist_name}")  # Debugging line
            csv_writer.writerow([year, rank, song_title, artist_name])

# %% [markdown]
# #### Scraping and Saving Lyrics for Both Decades

# %%
# Create lists of years for both decades
decade_1 = [str(year) for year in range(2000, 2010)]
decade_2 = [str(year) for year in range(2010, 2020)]

# Initialise lists to hold song data
songs_decade_1 = []
songs_decade_2 = []

for year in decade_1:
    song_info = scrape_billboard(year)
    formatted_data = format_song_data(song_info) 
    songs_decade_1.extend(formatted_data) 

for year in decade_2:
    song_info = scrape_billboard(year)
    formatted_data = format_song_data(song_info) 
    songs_decade_2.extend(formatted_data)

# %% [markdown]
# **00's**

# %%
# Iterate through each year in decade, scrape, format, append song data
for year in decade_1:
    song_info = scrape_billboard(year)
    formatted_data = format_song_data(song_info) 
    songs_decade_1.extend(formatted_data) 

    # Scrape lyrics for each song and save to file
    for year, rank, formatted_title, formatted_artist in formatted_data:
        lyrics = scrape_lyrics(formatted_title, formatted_artist)
        if lyrics:
            save_lyrics_to_file(year, lyrics)
            print(f"Lyrics for {formatted_title} by {formatted_artist} have been saved in {year} file.\n")
        else:
            print(f"Failed to scrape lyrics for: {formatted_title} by {formatted_artist} from {year}")
            
        time.sleep(10) # Use sleep to avoid triggering anti-bot measures
# Out:
# Lyrics for breathe by faithhill have been saved in 2000 file.
#
# Lyrics for smooth by santana have been saved in 2000 file.
#
# Lyrics for mariamaria by santana have been saved in 2000 file.
#
# Lyrics for iwannaknow by joe have been saved in 2000 file.
#
# Lyrics for everythingyouwant by verticalhorizon have been saved in 2000 file.
#
# Lyrics for saymyname by destinyschild have been saved in 2000 file.
#
# Lyrics for iknewilovedyou by savagegarden have been saved in 2000 file.
#
# Lyrics for amazed by lonestar have been saved in 2000 file.
#
# Lyrics for bent by matchbox20 have been saved in 2000 file.
#
# Lyrics for hewasntmanenough by tonibraxton have been saved in 2000 file.
#
# Lyrics for hangingbyamoment by lifehouse have been saved in 2001 file.
#
# Lyrics for fallin by aliciakeys have been saved in 2001 file.
#
# Lyrics for allforyou by janetjackson have been saved in 2001 file.
#
# Lyrics for dropsofjupiter by train have been saved in 2001 file.
#
# Lyrics for imreal by jenniferlopez have been saved in 2001 file.
#
# Lyrics for ifyouregone by matchbox20 have been saved in 2001 file.
#
# Lyrics for letmeblowyamind by eve have been saved in 2001 file.
#
# Lyrics for thankyou by dido have been saved in 2001 file.
#
# Lyrics for again by lennykravitz have been saved in 2001 file.
#
# Lyrics for independentwomen by destinyschild have been saved in 2001 file.
#
# Lyrics for howyouremindme by nickelback have been saved in 2002 file.
#
# Lyrics for foolish by ashanti have been saved in 2002 file.
#
# Lyrics for hotinherre by nelly have been saved in 2002 file.
#
# Lyrics for dilemma by nelly have been saved in 2002 file.
#
# Lyrics for whereveryouwillgo by calling have been saved in 2002 file.
#
# Lyrics for athousandmiles by vanessacarlton have been saved in 2002 file.
#
# Lyrics for intheend by linkinpark have been saved in 2002 file.
#
# Lyrics for whatsluv by fatjoe have been saved in 2002 file.
#
# Lyrics for ugotitbad by usher have been saved in 2002 file.
#
# Lyrics for blurry by puddleofmudd have been saved in 2002 file.
#
# Lyrics for indaclub by 50cent have been saved in 2003 file.
#
# Lyrics for ignition by rkelly have been saved in 2003 file.
#
# Lyrics for getbusy by seanpaul have been saved in 2003 file.
#
# Lyrics for crazyinlove by beyonceknowles have been saved in 2003 file.
#
# Lyrics for whenimgone by 3doorsdown have been saved in 2003 file.
#
# Lyrics for unwell by matchbox20 have been saved in 2003 file.
#
# Lyrics for rightthurr by chingy have been saved in 2003 file.
#
# Lyrics for missyou by aaliyah have been saved in 2003 file.
#
# Lyrics for picture by kidrock have been saved in 2003 file.
#
# Lyrics for bringmetolife by evanescence have been saved in 2003 file.
#
# Lyrics for yeah by usher have been saved in 2004 file.
#
# Lyrics for burn by usher have been saved in 2004 file.
#
# Lyrics for ifiaintgotyou by aliciakeys have been saved in 2004 file.
#
# Lyrics for thislove by maroon5 have been saved in 2004 file.
#
# Lyrics for thewayyoumove by outkast have been saved in 2004 file.
#
# Lyrics for thereason by hoobastank have been saved in 2004 file.
#
# Lyrics for idontwannaknow by mariowinans have been saved in 2004 file.
#
# Lyrics for heyya by outkast have been saved in 2004 file.
#
# Lyrics for goodies by ciara have been saved in 2004 file.
#
# Lyrics for leanback by terrorsquad have been saved in 2004 file.
#
# Lyrics for webelongtogether by mariahcarey have been saved in 2005 file.
#
# Lyrics for hollabackgirl by gwenstefani have been saved in 2005 file.
#
# Lyrics for letmeloveyou by mario have been saved in 2005 file.
#
# Lyrics for sinceubeengone by kellyclarkson have been saved in 2005 file.
#
# Lyrics for 12step by ciara have been saved in 2005 file.
#
# Lyrics for golddigger by kanyewest have been saved in 2005 file.
#
# Lyrics for boulevardofbrokendreams by greenday have been saved in 2005 file.
#
# Lyrics for candyshop by 50cent have been saved in 2005 file.
#
# Lyrics for dontcha by pussycatdolls have been saved in 2005 file.
#
# Lyrics for behindthesehazeleyes by kellyclarkson have been saved in 2005 file.
#
# Lyrics for badday by danielpowter have been saved in 2006 file.
#
# Lyrics for temperature by seanpaul have been saved in 2006 file.
#
# Lyrics for promiscuous by nellyfurtado have been saved in 2006 file.
#
# Lyrics for yourebeautiful by jamesblunt have been saved in 2006 file.
#
# Lyrics for hipsdontlie by shakira have been saved in 2006 file.
#
# Lyrics for unwritten by natashabedingfield have been saved in 2006 file.
#
# Lyrics for crazy by gnarlsbarkley have been saved in 2006 file.
#
# Lyrics for ridin by chamillionaire have been saved in 2006 file.
#
# Lyrics for sexyback by justintimberlake have been saved in 2006 file.
#
# Lyrics for checkonit by beyonceknowles have been saved in 2006 file.
#
# Lyrics for irreplaceable by beyonceknowles have been saved in 2007 file.
#
# Lyrics for umbrella by rihanna have been saved in 2007 file.
#
# Lyrics for thesweetescape by gwenstefani have been saved in 2007 file.
#
# Lyrics for biggirlsdontcry by fergie have been saved in 2007 file.
#
# Lyrics for buyuadrankshawtysnappin by tpain have been saved in 2007 file.
#
# Lyrics for beforehecheats by carrieunderwood have been saved in 2007 file.
#
# Lyrics for heytheredelilah by plainwhitets have been saved in 2007 file.
#
# Lyrics for iwannaloveyou by akon have been saved in 2007 file.
#
# Lyrics for sayitright by nellyfurtado have been saved in 2007 file.
#
# Lyrics for glamorous by fergie have been saved in 2007 file.
#
# Lyrics for low by florida have been saved in 2008 file.
#
# Lyrics for bleedinglove by leonalewis have been saved in 2008 file.
#
# Lyrics for noone by aliciakeys have been saved in 2008 file.
#
# Lyrics for lollipop by lilwayne have been saved in 2008 file.
#
# Lyrics for apologize by timbaland have been saved in 2008 file.
#
# Lyrics for noair by jordinsparks have been saved in 2008 file.
#
# Lyrics for lovesong by sarabareilles have been saved in 2008 file.
#
# Lyrics for loveinthisclub by usher have been saved in 2008 file.
#
# Lyrics for withyou by chrisbrown have been saved in 2008 file.
#
# Lyrics for boomboompow by blackeyedpeas have been saved in 2009 file.
#
# Lyrics for pokerface by ladygaga have been saved in 2009 file.
#
# Lyrics for justdance by ladygaga have been saved in 2009 file.
#
# Lyrics for igottafeelin by blackeyedpeas have been saved in 2009 file.
#
# Lyrics for lovestory by taylorswift have been saved in 2009 file.
#
# Lyrics for rightround by florida have been saved in 2009 file.
#
# Lyrics for imyours by jasonmraz have been saved in 2009 file.
#
# Lyrics for singleladiesputaringonit by beyonceknowles have been saved in 2009 file.
#
# Lyrics for heartless by kanyewest have been saved in 2009 file.
#
# Lyrics for givesyouhell by allamericanrejects have been saved in 2009 file.

# %% [markdown]
# **10's**

# %%
# Iterate through each year in decade, scrape, format, append song data
for year in decade_2:
    song_info = scrape_billboard(year)
    formatted_data = format_song_data(song_info) 
    songs_decade_2.extend(formatted_data) 

    # Scrape lyrics for each song and save to file
    for year, rank, formatted_title, formatted_artist in formatted_data:
        lyrics = scrape_lyrics(formatted_title, formatted_artist)
        if lyrics:
            save_lyrics_to_file(year, lyrics)
            print(f"Lyrics for {formatted_title} by {formatted_artist} have been saved in {year} file.\n")
        else:
            print(f"Failed to scrape lyrics for: {formatted_title} by {formatted_artist} from {year}")

        time.sleep(10) # Use sleep to avoid triggering anti-bot measures
# Out:
# Lyrics for tiktok by keha have been saved in 2010 file.
#
# Lyrics for needyounow by ladyantebellum have been saved in 2010 file.
#
# Lyrics for heysoulsister by train have been saved in 2010 file.
#
# Lyrics for californiagurls by katyperry have been saved in 2010 file.
#
# Lyrics for omg by usher have been saved in 2010 file.
#
# Lyrics for airplanes by bob have been saved in 2010 file.
#
# Lyrics for lovethewayyoulie by eminem have been saved in 2010 file.
#
# Lyrics for badromance by ladygaga have been saved in 2010 file.
#
# Lyrics for dynamite by taiocruz have been saved in 2010 file.
#
# Lyrics for breakyourheart by taiocruz have been saved in 2010 file.
#
# Lyrics for rollinginthedeep by adele have been saved in 2011 file.
#
# Lyrics for partyrockanthem by lmfao have been saved in 2011 file.
#
# Lyrics for firework by katyperry have been saved in 2011 file.
#
# Lyrics for et by katyperry have been saved in 2011 file.
#
# Lyrics for givemeeverything by pitbull have been saved in 2011 file.
#
# Lyrics for grenade by brunomars have been saved in 2011 file.
#
# Lyrics for fuckyou by ceelogreen have been saved in 2011 file.
#
# Lyrics for superbass by nickiminaj have been saved in 2011 file.
#
# Lyrics for moveslikejagger by maroon5 have been saved in 2011 file.
#
# Lyrics for justcantgetenough by blackeyedpeas have been saved in 2011 file.
#
# Lyrics for somebodythatiusedtoknow by gotye have been saved in 2012 file.
#
# Lyrics for callmemaybe by carlyraejepsen have been saved in 2012 file.
#
# Lyrics for weareyoung by fun have been saved in 2012 file.
#
# Lyrics for payphone by maroon5 have been saved in 2012 file.
#
# Lyrics for lights by elliegoulding have been saved in 2012 file.
#
# Lyrics for gladyoucame by wanted have been saved in 2012 file.
#
# Lyrics for whatdoesntkillyoustronger by kellyclarkson have been saved in 2012 file.
#
# Lyrics for wefoundlove by rihanna have been saved in 2012 file.
#
# Lyrics for starships by nickiminaj have been saved in 2012 file.
#
# Lyrics for whatmakesyoubeautiful by onedirection have been saved in 2012 file.
#
# Lyrics for thriftshop by macklemore have been saved in 2013 file.
#
# Lyrics for blurredlines by robinthicke have been saved in 2013 file.
#
# Lyrics for radioactive by imaginedragons have been saved in 2013 file.
#
# Lyrics for harlemshake by baauer have been saved in 2013 file.
#
# Lyrics for cantholdus by macklemore have been saved in 2013 file.
#
# Lyrics for mirrors by justintimberlake have been saved in 2013 file.
#
# Lyrics for justgivemeareason by pink have been saved in 2013 file.
#
# Lyrics for wheniwasyourman by brunomars have been saved in 2013 file.
#
# Lyrics for cruise by floridageorgialine have been saved in 2013 file.
#
# Lyrics for roar by katyperry have been saved in 2013 file.
#
# Lyrics for happy by pharrellwilliams have been saved in 2014 file.
#
# Lyrics for darkhorse by katyperry have been saved in 2014 file.
#
# Lyrics for allofme by johnlegend have been saved in 2014 file.
#
# Lyrics for fancy by iggyazalea have been saved in 2014 file.
#
# Lyrics for countingstars by onerepublic have been saved in 2014 file.
#
# Lyrics for talkdirty by jasonderulo have been saved in 2014 file.
#
# Lyrics for rude by magic have been saved in 2014 file.
#
# Lyrics for allaboutthatbass by meghantrainor have been saved in 2014 file.
#
# Lyrics for problem by arianagrande have been saved in 2014 file.
#
# Lyrics for staywithme by samsmith have been saved in 2014 file.
#
# Lyrics for uptownfunk by markronson have been saved in 2015 file.
#
# Lyrics for thinkingoutloud by edsheeran have been saved in 2015 file.
#
# Lyrics for seeyouagain by wizkhalifa have been saved in 2015 file.
#
# Lyrics for trapqueen by fettywap have been saved in 2015 file.
#
# Lyrics for sugar by maroon5 have been saved in 2015 file.
#
# Lyrics for shutupanddance by walkthemoon have been saved in 2015 file.
#
# Lyrics for blankspace by taylorswift have been saved in 2015 file.
#
# Lyrics for watchmewhipnaenae by silento have been saved in 2015 file.
#
# Lyrics for earnedit by weeknd have been saved in 2015 file.
#
# Lyrics for loveyourself by justinbieber have been saved in 2016 file.
#
# Lyrics for onedance by drake have been saved in 2016 file.
#
# Lyrics for work by rihanna have been saved in 2016 file.
#
# Lyrics for stressedout by twentyonepilots have been saved in 2016 file.
#
# Lyrics for panda by desiigner have been saved in 2016 file.
#
# Lyrics for hello by adele have been saved in 2016 file.
#
# Lyrics for dontletmedown by chainsmokers have been saved in 2016 file.
#
# Lyrics for cantstopthefeeling by justintimberlake have been saved in 2016 file.
#
# Lyrics for closer by chainsmokers have been saved in 2016 file.
#
# Lyrics for shapeofyou by edsheeran have been saved in 2017 file.
#
# Lyrics for despacito by luisfonsi have been saved in 2017 file.
#
# Lyrics for thatswhatilike by brunomars have been saved in 2017 file.
#
# Lyrics for humble by kendricklamar have been saved in 2017 file.
#
# Lyrics for somethingjustlikethis by chainsmokers have been saved in 2017 file.
#
# Lyrics for badandboujee by migos have been saved in 2017 file.
#
# Lyrics for closer by chainsmokers have been saved in 2017 file.
#
# Lyrics for bodylikeabackroad by samhunt have been saved in 2017 file.
#
# Lyrics for believer by imaginedragons have been saved in 2017 file.
#
# Lyrics for congratulations by postmalone have been saved in 2017 file.
#
# Lyrics for godsplan by drake have been saved in 2018 file.
#
# Lyrics for perfect by edsheeran have been saved in 2018 file.
#
# Lyrics for meanttobe by beberexha have been saved in 2018 file.
#
# Lyrics for havana by camilacabello have been saved in 2018 file.
#
# Lyrics for rockstar by postmalone have been saved in 2018 file.
#
# Lyrics for psycho by postmalone have been saved in 2018 file.
#
# Lyrics for ilikeit by cardi-b have been saved in 2018 file.
#
# Lyrics for themiddle by zedd have been saved in 2018 file.
#
# Lyrics for inmyfeelings by drake have been saved in 2018 file.
#
# Lyrics for girlslikeyou by maroon5 have been saved in 2018 file.
#
# Lyrics for oldtownroad by lilnasx have been saved in 2019 file.
#
# Lyrics for sunflower by postmalone have been saved in 2019 file.
#
# Lyrics for withoutme by halsey have been saved in 2019 file.
#
# Lyrics for badguy by billieeilish have been saved in 2019 file.
#
# Lyrics for wow by postmalone have been saved in 2019 file.
#
# Lyrics for happier by marshmello have been saved in 2019 file.
#
# Lyrics for 7rings by arianagrande have been saved in 2019 file.
#
# Lyrics for talk by khalid have been saved in 2019 file.
#
# Lyrics for sickomode by travisscott have been saved in 2019 file.
#
# Lyrics for sucker by jonasbrothers have been saved in 2019 file.

# %%
# Create a CSV file for all songs from both decades
all_songs = songs_decade_1 + songs_decade_2
create_csv_file(all_songs)
# Out:
# Writing to CSV: Year=2000, Rank=1, Title=breathe, Artist=faithhill
# Writing to CSV: Year=2000, Rank=2, Title=smooth, Artist=santana
# Writing to CSV: Year=2000, Rank=3, Title=mariamaria, Artist=santana
# Writing to CSV: Year=2000, Rank=4, Title=iwannaknow, Artist=joe
# Writing to CSV: Year=2000, Rank=5, Title=everythingyouwant, Artist=verticalhorizon
# Writing to CSV: Year=2000, Rank=6, Title=saymyname, Artist=destinyschild
# Writing to CSV: Year=2000, Rank=7, Title=iknewilovedyou, Artist=savagegarden
# Writing to CSV: Year=2000, Rank=8, Title=amazed, Artist=lonestar
# Writing to CSV: Year=2000, Rank=9, Title=bent, Artist=matchbox20
# Writing to CSV: Year=2000, Rank=10, Title=hewasntmanenough, Artist=tonibraxton
# Writing to CSV: Year=2001, Rank=1, Title=hangingbyamoment, Artist=lifehouse
# Writing to CSV: Year=2001, Rank=2, Title=fallin, Artist=aliciakeys
# Writing to CSV: Year=2001, Rank=3, Title=allforyou, Artist=janetjackson
# Writing to CSV: Year=2001, Rank=4, Title=dropsofjupiter, Artist=train
# Writing to CSV: Year=2001, Rank=5, Title=imreal, Artist=jenniferlopez
# Writing to CSV: Year=2001, Rank=6, Title=ifyouregone, Artist=matchbox20
# Writing to CSV: Year=2001, Rank=7, Title=letmeblowyamind, Artist=eve
# Writing to CSV: Year=2001, Rank=8, Title=thankyou, Artist=dido
# Writing to CSV: Year=2001, Rank=9, Title=again, Artist=lennykravitz
# Writing to CSV: Year=2001, Rank=10, Title=independentwomen, Artist=destinyschild
# Writing to CSV: Year=2002, Rank=1, Title=howyouremindme, Artist=nickelback
# Writing to CSV: Year=2002, Rank=2, Title=foolish, Artist=ashanti
# Writing to CSV: Year=2002, Rank=3, Title=hotinherre, Artist=nelly
# Writing to CSV: Year=2002, Rank=4, Title=dilemma, Artist=nelly
# Writing to CSV: Year=2002, Rank=5, Title=whereveryouwillgo, Artist=calling
# Writing to CSV: Year=2002, Rank=6, Title=athousandmiles, Artist=vanessacarlton
# Writing to CSV: Year=2002, Rank=7, Title=intheend, Artist=linkinpark
# Writing to CSV: Year=2002, Rank=8, Title=whatsluv, Artist=fatjoe
# Writing to CSV: Year=2002, Rank=9, Title=ugotitbad, Artist=usher
# Writing to CSV: Year=2002, Rank=10, Title=blurry, Artist=puddleofmudd
# Writing to CSV: Year=2003, Rank=1, Title=indaclub, Artist=50cent
# Writing to CSV: Year=2003, Rank=2, Title=ignition, Artist=rkelly
# Writing to CSV: Year=2003, Rank=3, Title=getbusy, Artist=seanpaul
# Writing to CSV: Year=2003, Rank=4, Title=crazyinlove, Artist=beyonceknowles
# Writing to CSV: Year=2003, Rank=5, Title=whenimgone, Artist=3doorsdown
# Writing to CSV: Year=2003, Rank=6, Title=unwell, Artist=matchbox20
# Writing to CSV: Year=2003, Rank=7, Title=rightthurr, Artist=chingy
# Writing to CSV: Year=2003, Rank=8, Title=missyou, Artist=aaliyah
# Writing to CSV: Year=2003, Rank=9, Title=picture, Artist=kidrock
# Writing to CSV: Year=2003, Rank=10, Title=bringmetolife, Artist=evanescence
# Writing to CSV: Year=2004, Rank=1, Title=yeah, Artist=usher
# Writing to CSV: Year=2004, Rank=2, Title=burn, Artist=usher
# Writing to CSV: Year=2004, Rank=3, Title=ifiaintgotyou, Artist=aliciakeys
# Writing to CSV: Year=2004, Rank=4, Title=thislove, Artist=maroon5
# Writing to CSV: Year=2004, Rank=5, Title=thewayyoumove, Artist=outkast
# Writing to CSV: Year=2004, Rank=6, Title=thereason, Artist=hoobastank
# Writing to CSV: Year=2004, Rank=7, Title=idontwannaknow, Artist=mariowinans
# Writing to CSV: Year=2004, Rank=8, Title=heyya, Artist=outkast
# Writing to CSV: Year=2004, Rank=9, Title=goodies, Artist=ciara
# Writing to CSV: Year=2004, Rank=10, Title=leanback, Artist=terrorsquad
# Writing to CSV: Year=2005, Rank=1, Title=webelongtogether, Artist=mariahcarey
# Writing to CSV: Year=2005, Rank=2, Title=hollabackgirl, Artist=gwenstefani
# Writing to CSV: Year=2005, Rank=3, Title=letmeloveyou, Artist=mario
# Writing to CSV: Year=2005, Rank=4, Title=sinceubeengone, Artist=kellyclarkson
# Writing to CSV: Year=2005, Rank=5, Title=12step, Artist=ciara
# Writing to CSV: Year=2005, Rank=6, Title=golddigger, Artist=kanyewest
# Writing to CSV: Year=2005, Rank=7, Title=boulevardofbrokendreams, Artist=greenday
# Writing to CSV: Year=2005, Rank=8, Title=candyshop, Artist=50cent
# Writing to CSV: Year=2005, Rank=9, Title=dontcha, Artist=pussycatdolls
# Writing to CSV: Year=2005, Rank=10, Title=behindthesehazeleyes, Artist=kellyclarkson
# Writing to CSV: Year=2006, Rank=1, Title=badday, Artist=danielpowter
# Writing to CSV: Year=2006, Rank=2, Title=temperature, Artist=seanpaul
# Writing to CSV: Year=2006, Rank=3, Title=promiscuous, Artist=nellyfurtado
# Writing to CSV: Year=2006, Rank=4, Title=yourebeautiful, Artist=jamesblunt
# Writing to CSV: Year=2006, Rank=5, Title=hipsdontlie, Artist=shakira
# Writing to CSV: Year=2006, Rank=6, Title=unwritten, Artist=natashabedingfield
# Writing to CSV: Year=2006, Rank=7, Title=crazy, Artist=gnarlsbarkley
# Writing to CSV: Year=2006, Rank=8, Title=ridin, Artist=chamillionaire
# Writing to CSV: Year=2006, Rank=9, Title=sexyback, Artist=justintimberlake
# Writing to CSV: Year=2006, Rank=10, Title=checkonit, Artist=beyonceknowles
# Writing to CSV: Year=2007, Rank=1, Title=irreplaceable, Artist=beyonceknowles
# Writing to CSV: Year=2007, Rank=2, Title=umbrella, Artist=rihanna
# Writing to CSV: Year=2007, Rank=3, Title=thesweetescape, Artist=gwenstefani
# Writing to CSV: Year=2007, Rank=4, Title=biggirlsdontcry, Artist=fergie
# Writing to CSV: Year=2007, Rank=5, Title=buyuadrankshawtysnappin, Artist=tpain
# Writing to CSV: Year=2007, Rank=6, Title=beforehecheats, Artist=carrieunderwood
# Writing to CSV: Year=2007, Rank=7, Title=heytheredelilah, Artist=plainwhitets
# Writing to CSV: Year=2007, Rank=8, Title=iwannaloveyou, Artist=akon
# Writing to CSV: Year=2007, Rank=9, Title=sayitright, Artist=nellyfurtado
# Writing to CSV: Year=2007, Rank=10, Title=glamorous, Artist=fergie
# Writing to CSV: Year=2008, Rank=1, Title=low, Artist=florida
# Writing to CSV: Year=2008, Rank=2, Title=bleedinglove, Artist=leonalewis
# Writing to CSV: Year=2008, Rank=3, Title=noone, Artist=aliciakeys
# Writing to CSV: Year=2008, Rank=4, Title=lollipop, Artist=lilwayne
# Writing to CSV: Year=2008, Rank=5, Title=apologize, Artist=timbaland
# Writing to CSV: Year=2008, Rank=6, Title=noair, Artist=jordinsparks
# Writing to CSV: Year=2008, Rank=7, Title=lovesong, Artist=sarabareilles
# Writing to CSV: Year=2008, Rank=8, Title=loveinthisclub, Artist=usher
# Writing to CSV: Year=2008, Rank=9, Title=withyou, Artist=chrisbrown
# Writing to CSV: Year=2009, Rank=1, Title=boomboompow, Artist=blackeyedpeas
# Writing to CSV: Year=2009, Rank=2, Title=pokerface, Artist=ladygaga
# Writing to CSV: Year=2009, Rank=3, Title=justdance, Artist=ladygaga
# Writing to CSV: Year=2009, Rank=4, Title=igottafeelin, Artist=blackeyedpeas
# Writing to CSV: Year=2009, Rank=5, Title=lovestory, Artist=taylorswift
# Writing to CSV: Year=2009, Rank=6, Title=rightround, Artist=florida
# Writing to CSV: Year=2009, Rank=7, Title=imyours, Artist=jasonmraz
# Writing to CSV: Year=2009, Rank=8, Title=singleladiesputaringonit, Artist=beyonceknowles
# Writing to CSV: Year=2009, Rank=9, Title=heartless, Artist=kanyewest
# Writing to CSV: Year=2009, Rank=10, Title=givesyouhell, Artist=allamericanrejects
# Writing to CSV: Year=2010, Rank=1, Title=tiktok, Artist=keha
# Writing to CSV: Year=2010, Rank=2, Title=needyounow, Artist=ladyantebellum
# Writing to CSV: Year=2010, Rank=3, Title=heysoulsister, Artist=train
# Writing to CSV: Year=2010, Rank=4, Title=californiagurls, Artist=katyperry
# Writing to CSV: Year=2010, Rank=5, Title=omg, Artist=usher
# Writing to CSV: Year=2010, Rank=6, Title=airplanes, Artist=bob
# Writing to CSV: Year=2010, Rank=7, Title=lovethewayyoulie, Artist=eminem
# Writing to CSV: Year=2010, Rank=8, Title=badromance, Artist=ladygaga
# Writing to CSV: Year=2010, Rank=9, Title=dynamite, Artist=taiocruz
# Writing to CSV: Year=2010, Rank=10, Title=breakyourheart, Artist=taiocruz
# Writing to CSV: Year=2011, Rank=1, Title=rollinginthedeep, Artist=adele
# Writing to CSV: Year=2011, Rank=2, Title=partyrockanthem, Artist=lmfao
# Writing to CSV: Year=2011, Rank=3, Title=firework, Artist=katyperry
# Writing to CSV: Year=2011, Rank=4, Title=et, Artist=katyperry
# Writing to CSV: Year=2011, Rank=5, Title=givemeeverything, Artist=pitbull
# Writing to CSV: Year=2011, Rank=6, Title=grenade, Artist=brunomars
# Writing to CSV: Year=2011, Rank=7, Title=fuckyou, Artist=ceelogreen
# Writing to CSV: Year=2011, Rank=8, Title=superbass, Artist=nickiminaj
# Writing to CSV: Year=2011, Rank=9, Title=moveslikejagger, Artist=maroon5
# Writing to CSV: Year=2011, Rank=10, Title=justcantgetenough, Artist=blackeyedpeas
# Writing to CSV: Year=2012, Rank=1, Title=somebodythatiusedtoknow, Artist=gotye
# Writing to CSV: Year=2012, Rank=2, Title=callmemaybe, Artist=carlyraejepsen
# Writing to CSV: Year=2012, Rank=3, Title=weareyoung, Artist=fun
# Writing to CSV: Year=2012, Rank=4, Title=payphone, Artist=maroon5
# Writing to CSV: Year=2012, Rank=5, Title=lights, Artist=elliegoulding
# Writing to CSV: Year=2012, Rank=6, Title=gladyoucame, Artist=wanted
# Writing to CSV: Year=2012, Rank=7, Title=whatdoesntkillyoustronger, Artist=kellyclarkson
# Writing to CSV: Year=2012, Rank=8, Title=wefoundlove, Artist=rihanna
# Writing to CSV: Year=2012, Rank=9, Title=starships, Artist=nickiminaj
# Writing to CSV: Year=2012, Rank=10, Title=whatmakesyoubeautiful, Artist=onedirection
# Writing to CSV: Year=2013, Rank=1, Title=thriftshop, Artist=macklemore
# Writing to CSV: Year=2013, Rank=2, Title=blurredlines, Artist=robinthicke
# Writing to CSV: Year=2013, Rank=3, Title=radioactive, Artist=imaginedragons
# Writing to CSV: Year=2013, Rank=4, Title=harlemshake, Artist=baauer
# Writing to CSV: Year=2013, Rank=5, Title=cantholdus, Artist=macklemore
# Writing to CSV: Year=2013, Rank=6, Title=mirrors, Artist=justintimberlake
# Writing to CSV: Year=2013, Rank=7, Title=justgivemeareason, Artist=pink
# Writing to CSV: Year=2013, Rank=8, Title=wheniwasyourman, Artist=brunomars
# Writing to CSV: Year=2013, Rank=9, Title=cruise, Artist=floridageorgialine
# Writing to CSV: Year=2013, Rank=10, Title=roar, Artist=katyperry
# Writing to CSV: Year=2014, Rank=1, Title=happy, Artist=pharrellwilliams
# Writing to CSV: Year=2014, Rank=2, Title=darkhorse, Artist=katyperry
# Writing to CSV: Year=2014, Rank=3, Title=allofme, Artist=johnlegend
# Writing to CSV: Year=2014, Rank=4, Title=fancy, Artist=iggyazalea
# Writing to CSV: Year=2014, Rank=5, Title=countingstars, Artist=onerepublic
# Writing to CSV: Year=2014, Rank=6, Title=talkdirty, Artist=jasonderulo
# Writing to CSV: Year=2014, Rank=7, Title=rude, Artist=magic
# Writing to CSV: Year=2014, Rank=8, Title=allaboutthatbass, Artist=meghantrainor
# Writing to CSV: Year=2014, Rank=9, Title=problem, Artist=arianagrande
# Writing to CSV: Year=2014, Rank=10, Title=staywithme, Artist=samsmith
# Writing to CSV: Year=2015, Rank=1, Title=uptownfunk, Artist=markronson
# Writing to CSV: Year=2015, Rank=2, Title=thinkingoutloud, Artist=edsheeran
# Writing to CSV: Year=2015, Rank=3, Title=seeyouagain, Artist=wizkhalifa
# Writing to CSV: Year=2015, Rank=4, Title=trapqueen, Artist=fettywap
# Writing to CSV: Year=2015, Rank=5, Title=sugar, Artist=maroon5
# Writing to CSV: Year=2015, Rank=6, Title=shutupanddance, Artist=walkthemoon
# Writing to CSV: Year=2015, Rank=7, Title=blankspace, Artist=taylorswift
# Writing to CSV: Year=2015, Rank=8, Title=watchmewhipnaenae, Artist=silento
# Writing to CSV: Year=2015, Rank=9, Title=earnedit, Artist=weeknd
# Writing to CSV: Year=2016, Rank=1, Title=loveyourself, Artist=justinbieber
# Writing to CSV: Year=2016, Rank=3, Title=onedance, Artist=drake
# Writing to CSV: Year=2016, Rank=4, Title=work, Artist=rihanna
# Writing to CSV: Year=2016, Rank=5, Title=stressedout, Artist=twentyonepilots
# Writing to CSV: Year=2016, Rank=6, Title=panda, Artist=desiigner
# Writing to CSV: Year=2016, Rank=7, Title=hello, Artist=adele
# Writing to CSV: Year=2016, Rank=8, Title=dontletmedown, Artist=chainsmokers
# Writing to CSV: Year=2016, Rank=9, Title=cantstopthefeeling, Artist=justintimberlake
# Writing to CSV: Year=2016, Rank=10, Title=closer, Artist=chainsmokers
# Writing to CSV: Year=2017, Rank=1, Title=shapeofyou, Artist=edsheeran
# Writing to CSV: Year=2017, Rank=2, Title=despacito, Artist=luisfonsi
# Writing to CSV: Year=2017, Rank=3, Title=thatswhatilike, Artist=brunomars
# Writing to CSV: Year=2017, Rank=4, Title=humble, Artist=kendricklamar
# Writing to CSV: Year=2017, Rank=5, Title=somethingjustlikethis, Artist=chainsmokers
# Writing to CSV: Year=2017, Rank=6, Title=badandboujee, Artist=migos
# Writing to CSV: Year=2017, Rank=7, Title=closer, Artist=chainsmokers
# Writing to CSV: Year=2017, Rank=8, Title=bodylikeabackroad, Artist=samhunt
# Writing to CSV: Year=2017, Rank=9, Title=believer, Artist=imaginedragons
# Writing to CSV: Year=2017, Rank=10, Title=congratulations, Artist=postmalone
# Writing to CSV: Year=2018, Rank=1, Title=godsplan, Artist=drake
# Writing to CSV: Year=2018, Rank=2, Title=perfect, Artist=edsheeran
# Writing to CSV: Year=2018, Rank=3, Title=meanttobe, Artist=beberexha
# Writing to CSV: Year=2018, Rank=4, Title=havana, Artist=camilacabello
# Writing to CSV: Year=2018, Rank=5, Title=rockstar, Artist=postmalone
# Writing to CSV: Year=2018, Rank=6, Title=psycho, Artist=postmalone
# Writing to CSV: Year=2018, Rank=7, Title=ilikeit, Artist=cardi-b
# Writing to CSV: Year=2018, Rank=8, Title=themiddle, Artist=zedd
# Writing to CSV: Year=2018, Rank=9, Title=inmyfeelings, Artist=drake
# Writing to CSV: Year=2018, Rank=10, Title=girlslikeyou, Artist=maroon5
# Writing to CSV: Year=2019, Rank=1, Title=oldtownroad, Artist=lilnasx
# Writing to CSV: Year=2019, Rank=2, Title=sunflower, Artist=postmalone
# Writing to CSV: Year=2019, Rank=3, Title=withoutme, Artist=halsey
# Writing to CSV: Year=2019, Rank=4, Title=badguy, Artist=billieeilish
# Writing to CSV: Year=2019, Rank=5, Title=wow, Artist=postmalone
# Writing to CSV: Year=2019, Rank=6, Title=happier, Artist=marshmello
# Writing to CSV: Year=2019, Rank=7, Title=7rings, Artist=arianagrande
# Writing to CSV: Year=2019, Rank=8, Title=talk, Artist=khalid
# Writing to CSV: Year=2019, Rank=9, Title=sickomode, Artist=travisscott
# Writing to CSV: Year=2019, Rank=10, Title=sucker, Artist=jonasbrothers
